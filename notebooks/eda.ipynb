# %%
import pandas as pd

# %%
df_train = pd.read_csv("/Users/ronaldojr/Projects/predicting_vehicle_purchases/data/train.csv")
df_test = pd.read_csv("/Users/ronaldojr/Projects/predicting_vehicle_purchases/data/test.csv")

# %%
df_train.head()
# Out:
#    id  Age  Annual_Income_USD  Daily_Commute_km  Number_of_Cars_Owned  \
# 0   0   66            92887.0              23.4                     2
# 1   1   38            30000.0               5.0                     1
# 2   2   26            94389.0              36.8                     1
# 3   3   66            73580.0              23.7                     2
# 4   4   54            57898.0              50.8                     1
#
#    Charging_Stations_Near_Home  Charging_Stations_Near_Work  \
# 0                            3                            7
# 1                            2                            2
# 2                            8                           15
# 3                            6                            9
# 4                            2                            3
#
#    Environmental_Concern_Level  Gender City_Type Current_Car_Type  \
# 0                          1.0    Male  Suburban            Sedan
# ...

# %%
df_train.columns.to_list()
# Out:
# ['id',
#  'Age',
#  'Annual_Income_USD',
#  'Daily_Commute_km',
#  'Number_of_Cars_Owned',
#  'Charging_Stations_Near_Home',
#  'Charging_Stations_Near_Work',
#  'Environmental_Concern_Level',
#  'Gender',
#  'City_Type',
#  'Current_Car_Type',
#  'Home_Charging_Possible',
#  'Subsidy_Available',
#  'Range_Anxiety_Level',
#  'Will_Buy_EV']

# %%
df_train['Annual_Income_USD'].describe()
# Out:
# count    668665.000000
# mean      84769.266989
# std       28648.029042
# min       30000.000000
# 25%       67376.000000
# 50%       84880.000000
# 75%      102753.000000
# max      188549.000000
# Name: Annual_Income_USD, dtype: float64

# %%
import matplotlib.pyplot as plt

df_train['Annual_Income_USD'].plot.box
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df_train['Range_Anxiety_Level'].value_counts()
# Out:
# Range_Anxiety_Level
# Low       603972
# Medium     62499
# High        2194
# Name: count, dtype: int64
